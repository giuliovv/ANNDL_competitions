# %% [markdown]
# <a href="https://colab.research.google.com/github/giuliovv/ANNDL_competitions/blob/master/2_RNN/giulio_model_wavenet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Wavenet

# %% [markdown]
# ### Connect to drive and import libraries

# %%
import os

colab = "True" #@param ['True','False']
if colab == "True":
  from google.colab import drive
  drive.mount('/gdrive')
  # %cd /gdrive/MyDrive/Colab Notebooks
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).
# /gdrive/MyDrive/Colab Notebooks

# %%
# !pip install keras-tcn --no-dependencies
# Out:
# Collecting keras-tcn
#   Downloading keras_tcn-3.4.0-py2.py3-none-any.whl (13 kB)
# Installing collected packages: keras-tcn
# Successfully installed keras-tcn-3.4.0

# %%
from tcn import TCN, tcn_full_summary

# %%
import pandas as pd
import matplotlib.pyplot as plt
import random
import tensorflow as tf
import numpy as np

from tensorflow import keras

tfk = tf.keras
tfkl = tf.keras.layers

# %% [markdown]
# ### Data inspection

# %%
plt.rcParams["figure.figsize"] = (20,10)
data = pd.read_csv("Training.csv")
data.head()
# Out:
#    Sponginess  Wonder level  ...  Soap slipperiness  Hype root
# 0     7.97698       4.33494  ...          51.681460    3.65434
# 1     8.07824       4.44616  ...          51.563598    3.47672
# 2     8.02844       4.22372  ...          50.863080    3.47672
# 3     8.02844       4.22372  ...          45.841581    3.47672
# 4     7.87572       4.44616  ...          47.126421    3.47672
#
# [5 rows x 7 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68528 entries, 0 to 68527
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Sponginess          68528 non-null  float64
#  1   Wonder level        68528 non-null  float64
#  2   Crunchiness         68528 non-null  float64
#  3   Loudness on impact  68528 non-null  float64
#  4   Meme creativity     68528 non-null  float64
#  5   Soap slipperiness   68528 non-null  float64
#  6   Hype root           68528 non-null  float64
# dtypes: float64(7)
# memory usage: 3.7 MB

# %%
data.plot(subplots=True, layout=(4,2))
data.corr().style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_8fc0d79a_6440_11ec_a8bc_0242ac1c0002row0_col0,#T_8fc0d79a_6440_11ec_a8bc_0242ac1c0002row1_col1,#T_8fc0d79a_6440_11ec_a8bc_0242ac1c0002row2_col2,#T_8fc0d79a_6440_11ec_a8bc_0242ac1c0002row3_col3,#T_8fc0d79a_6440_11ec_a8bc_0242ac1c0002row4_col4,#T_8fc0d79a_6440_11ec_a8bc_0242ac1c0002row5_col5,#T_8fc0d79a_6440_11ec_a8bc_0242ac1c0002row6_col6{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_8fc0d79a_6440_11ec_a8bc_0242ac1c0002row0_col1{
#             background-color:  #799cf8;
#             color:  #000000;
#         }#T_8fc0d79a_6440_11ec_a8bc_0242ac1c0002row0_col2{
#             background-color:  #96b7ff;
#             color:  #000000;
#         }#T_8fc0d79a_6440_11ec_a8bc_0242ac1c0002row0_col3{
#             background-color:  #516ddb;
#             color:  #000000;
#         }#T_8fc0d79a_6440_11ec_a8bc_0242ac1c0002row0_col4{
#             background-color:  #b2ccfb;
#             color:  #000000;
#         }#T_8fc0d79a_6440_11ec_a8bc_0242ac1c0002row0_col5{
#             background-color:  #536edd;
#             color:  #000000;
#         }#T_8fc0d79a_6440_11ec_a8bc_0242ac1c0002row0_col6{
#             background-color:  #81a4fb;
#             color:  #000000;
#         }#T_8fc0d79a_6440_11ec_a8bc_0242ac1c0002row1_col0{
#             background-color:  #6a8bef;
#             color:  #000000;
#         }#T_8fc0d79a_6440_11ec_a8bc_0242ac1c0002row1_col2,#T_8fc0d79a_6440_11ec_a8bc_0242ac1c0002row3_col4{
#             background-color:  #5673e0;
#             color:  #000000;
#         }#T_8fc0d79a_6440_11ec_a8bc_0242ac1c0002row1_col3{
#             background-color:  #cd423b;
#             color:  #f1f1f1;
#         }#T_8fc0d79a_6440_11ec_a8bc_0242ac1c0002row1_col4{
#             background-color:  #bed2f6;
#             color:  #000000;
#         }#T_8fc0d79a_6440_11ec_a8bc_0242ac1c0002row1_col5{
#             background-color:  #7a9df8;
#             color:  #000000;
#         }#T_8fc0d79a_6440_11ec_a8bc_0242ac1c0002row1_col6{
#             background-color:  #5d7ce6;
#             color:  #000000;
#         }#T_8fc0d79a_6440_11ec_a8bc_0242ac1c0002row2_col0{
#             background-color:  #7b9ff9;
#             color:  #000000;
#         }#T_8fc0d79a_6440_11ec_a8bc_0242ac1c0002row2_col1{
#             background-color:  #4961d2;
#             color:  #f1f1f1;
#         }#T_8fc0d79a_6440_11ec_a8bc_0242ac1c0002row2_col3{
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }#T_8fc0d79a_6440_11ec_a8bc_0242ac1c0002row2_col4,#T_8fc0d79a_6440_11ec_a8bc_0242ac1c0002row6_col0{
#             background-color:  #4f69d9;
#             color:  #000000;
#         }#T_8fc0d79a_6440_11ec_a8bc_0242ac1c0002row2_col5{
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }#T_8fc0d79a_6440_11ec_a8bc_0242ac1c0002row2_col6,#T_8fc0d79a_6440_11ec_a8bc_0242ac1c0002row6_col2{
#             background-color:  #b8122a;
#             color:  #f1f1f1;
#         }#T_8fc0d79a_6440_11ec_a8bc_0242ac1c0002row3_col0,#T_8fc0d79a_6440_11ec_a8bc_0242ac1c0002row4_col2,#T_8fc0d79a_6440_11ec_a8bc_0242ac1c0002row4_col6,#T_8fc0d79a_6440_11ec_a8bc_0242ac1c0002row6_col1,#T_8fc0d79a_6440_11ec_a8bc_0242ac1c0002row6_col3,#T_8fc0d79a_6440_11ec_a8bc_0242ac1c0002row6_col4,#T_8fc0d79a_6440_11ec_a8bc_0242ac1c0002row6_col5{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_8fc0d79a_6440_11ec_a8bc_0242ac1c0002row3_col1{
#             background-color:  #cf453c;
#             color:  #f1f1f1;
#         }#T_8fc0d79a_6440_11ec_a8bc_0242ac1c0002row3_col2{
#             background-color:  #465ecf;
#             color:  #f1f1f1;
#         }#T_8fc0d79a_6440_11ec_a8bc_0242ac1c0002row3_col5,#T_8fc0d79a_6440_11ec_a8bc_0242ac1c0002row5_col3{
#             background-color:  #779af7;
#             color:  #000000;
#         }#T_8fc0d79a_6440_11ec_a8bc_0242ac1c0002row3_col6{
#             background-color:  #5470de;
#             color:  #000000;
#         }#T_8fc0d79a_6440_11ec_a8bc_0242ac1c0002row4_col0{
#             background-color:  #89acfd;
#             color:  #000000;
#         }#T_8fc0d79a_6440_11ec_a8bc_0242ac1c0002row4_col1{
#             background-color:  #a5c3fe;
#             color:  #000000;
#         }#T_8fc0d79a_6440_11ec_a8bc_0242ac1c0002row4_col3,#T_8fc0d79a_6440_11ec_a8bc_0242ac1c0002row5_col0{
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }#T_8fc0d79a_6440_11ec_a8bc_0242ac1c0002row4_col5{
#             background-color:  #4358cb;
#             color:  #f1f1f1;
#         }#T_8fc0d79a_6440_11ec_a8bc_0242ac1c0002row5_col1{
#             background-color:  #7295f4;
#             color:  #000000;
#         }#T_8fc0d79a_6440_11ec_a8bc_0242ac1c0002row5_col2{
#             background-color:  #445acc;
#             color:  #f1f1f1;
#         }#T_8fc0d79a_6440_11ec_a8bc_0242ac1c0002row5_col4{
#             background-color:  #5e7de7;
#             color:  #000000;
#         }#T_8fc0d79a_6440_11ec_a8bc_0242ac1c0002row5_col6{
#             background-color:  #5572df;
#             color:  #000000;
#         }</style><table id="T_8fc0d79a_6440_11ec_a8bc_0242ac1c0002" class="dataframe"><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Sponginess</th>        <th class="col_heading level0 col1" >Wonder level</th>        <th class="col_heading level0 col2" >Crunchiness</th>        <th class="col_heading level0 col3" >Loudness on impact</th>        <th class="col_heading level0 col4" >Meme creativity</th>        <th class="col_heading level0 col5" >Soap slipperiness</th>        <th class="col_heading level0 col6" >Hype root</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_8fc0d79a_6440_11ec_a8bc_0242ac1c0002level0_row0" class="row_heading level0 row0" >Sponginess</th>
#                         <td id="T_8fc0d79a_6440_11ec_a8bc_0242ac1c0002row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_8fc0d79a_6440_11ec_a8bc_0242ac1c0002row0_col1" class="data row0 col1" >0.253002</td>
#                         <td id="T_8fc0d79a_6440_11ec_a8bc_0242ac1c0002row0_col2" class="data row0 col2" >0.297509</td>
#                         <td id="T_8fc0d79a_6440_11ec_a8bc_0242ac1c0002row0_col3" class="data row0 col3" >0.121744</td>
#                         <td id="T_8fc0d79a_6440_11ec_a8bc_0242ac1c0002row0_col4" class="data row0 col4" >0.331200</td>
#                         <td id="T_8fc0d79a_6440_11ec_a8bc_0242ac1c0002row0_col5" class="data row0 col5" >0.127885</td>
#                         <td id="T_8fc0d79a_6440_11ec_a8bc_0242ac1c0002row0_col6" class="data row0 col6" >0.183141</td>
#             </tr>
#             <tr>
#                         <th id="T_8fc0d79a_6440_11ec_a8bc_0242ac1c0002level0_row1" class="row_heading level0 row1" >Wonder level</th>
#                         <td id="T_8fc0d79a_6440_11ec_a8bc_0242ac1c0002row1_col0" class="data row1 col0" >0.253002</td>
#                         <td id="T_8fc0d79a_6440_11ec_a8bc_0242ac1c0002row1_col1" class="data row1 col1" >1.000000</td>
#                         <td id="T_8fc0d79a_6440_11ec_a8bc_0242ac1c0002row1_col2" class="data row1 col2" >0.119078</td>
#                         <td id="T_8fc0d79a_6440_11ec_a8bc_0242ac1c0002row1_col3" class="data row1 col3" >0.930254</td>
#                         <td id="T_8fc0d79a_6440_11ec_a8bc_0242ac1c0002row1_col4" class="data row1 col4" >0.367438</td>
#                         <td id="T_8fc0d79a_6440_11ec_a8bc_0242ac1c0002row1_col5" class="data row1 col5" >0.237021</td>
#                         <td id="T_8fc0d79a_6440_11ec_a8bc_0242ac1c0002row1_col6" class="data row1 col6" >0.074392</td>
#             </tr>
#             <tr>
#                         <th id="T_8fc0d79a_6440_11ec_a8bc_0242ac1c0002level0_row2" class="row_heading level0 row2" >Crunchiness</th>
#                         <td id="T_8fc0d79a_6440_11ec_a8bc_0242ac1c0002row2_col0" class="data row2 col0" >0.297509</td>
#                         <td id="T_8fc0d79a_6440_11ec_a8bc_0242ac1c0002row2_col1" class="data row2 col1" >0.119078</td>
#                         <td id="T_8fc0d79a_6440_11ec_

# %% [markdown]
# ### Set seed for reproducibility

# %%
# Random seed for reproducibility
seed = 42

random.seed(seed)
os.environ['PYTHONHASHSEED'] = str(seed)
np.random.seed(seed)
tf.random.set_seed(seed)
tf.compat.v1.set_random_seed(seed)

# %%
data_or = data
# data = data.drop(["Hype root", "Loudness on impact"], axis=1)

# %% [markdown]
# ### Creating training and testing data

# %%
TEST_SPLIT = 0.1

test_size = int(len(data)*TEST_SPLIT)
X_train_raw = data.iloc[:-test_size]
# y_train_raw = y.iloc[:-test_size]
X_test_raw = data.iloc[-test_size:]
# y_test_raw = y.iloc[-test_size:]
print(X_train_raw.shape, X_test_raw.shape)

# Normalize both features and labels
X_min = X_train_raw.min()
X_max = X_train_raw.max()

X_train_raw = (X_train_raw-X_min)/(X_max-X_min)
X_test_raw = (X_test_raw-X_min)/(X_max-X_min)

# Normalize soap sliperiness
# X_sloap_slip = X_train_raw["Soap slipperiness"]
# X_train_raw["Soap slipperiness"] = (X_sloap_slip - X_sloap_slip.min())/(X_sloap_slip.max()-X_sloap_slip.min())
# X_test_raw["Soap slipperiness"] = (X_test_raw["Soap slipperiness"] - X_sloap_slip.min())/(X_sloap_slip.max()-X_sloap_slip.min())

plt.figure(figsize=(17,5))
plt.plot(X_train_raw['Sponginess'], label='Train')
plt.plot(X_test_raw['Sponginess'], label='Test')
plt.title('Train-Test Split')
plt.legend()
plt.show()
# Out:
# (61676, 7) (6852, 7)

# %% [markdown]
# Window:
#
# 200 - ok
#
# 300 -ok
#
# 500 - very bad

# %%
window = 5000
stride = 10

# %%
future = data[-window:]
future = (future-X_min)/(X_max-X_min)
future = np.expand_dims(future, axis=0)
future.shape
# Out:
# (1, 1600, 7)

# %%
def build_sequences(df, target_labels=['pollution'], window=200, stride=20, telescope=100):
    # Sanity check to avoid runtime errors
    assert window % stride == 0
    dataset = []
    labels = []
    temp_df = df.copy().values
    temp_label = df[target_labels].copy().values
    padding_len = len(df)%window

    if(padding_len != 0):
        # Compute padding length
        padding_len = window - len(df)%window
        padding = np.zeros((padding_len,temp_df.shape[1]), dtype='float64')
        temp_df = np.concatenate((padding,df))
        padding = np.zeros((padding_len,temp_label.shape[1]), dtype='float64')
        temp_label = np.concatenate((padding,temp_label))
        assert len(temp_df) % window == 0

    for idx in np.arange(0,len(temp_df)-window-telescope,stride):
        dataset.append(temp_df[idx:idx+window])
        labels.append(temp_label[idx+window:idx+window+telescope])

    dataset = np.array(dataset)
    labels = np.array(labels)
    return dataset, labels

# %%
target_labels = data.columns
telescope = 1

# %%
X_train, y_train = build_sequences(X_train_raw, target_labels, window, stride, telescope)
X_test, y_test = build_sequences(X_test_raw, target_labels, window, stride, telescope)
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((5994, 1600, 7), (5994, 864, 7), (554, 1600, 7), (554, 864, 7))

# %%
def inspect_multivariate(X, y, columns, telescope, idx=None):
    if(idx==None):
        idx=np.random.randint(0,len(X))

    figs, axs = plt.subplots(len(columns), 1, sharex=True, figsize=(17,17))
    for i, col in enumerate(columns):
        axs[i].plot(np.arange(len(X[0,:,i])), X[idx,:,i])
        axs[i].scatter(np.arange(len(X[0,:,i]), len(X_train[0,:,i])+telescope), y[idx,:,i], color='orange')
        axs[i].set_title(col)
        axs[i].set_ylim(0,1)
    plt.show()

# %%
inspect_multivariate(X_train, y_train, target_labels, telescope)

# %%
input_shape = X_train.shape[1:]
output_shape = y_train.shape[1:]
batch_size = 64
epochs = 200

# %% [markdown]
# Results:
# BI(LSTM(64))
# c1d
# maxpool
# BI(LSTM(128))
# c1d
# averagepool
# dropout
# 0.0093

# %% [markdown]
# ### Building network (Multivariate forecasting-direct)

# %%
def build_wavenet(input_shape, output_shape):
    model = keras.models.Sequential()

    # Build the neural network layer by layer
    # input_layer = tfkl.Input(shape=input_shape, name='Input')

    tcn_layer = TCN(input_shape=input_shape)
    print('Receptive field size =', tcn_layer.receptive_field)

    model.add(tcn_layer)


    model.add(tfkl.Dense(output_shape[-1]*output_shape[-2], activation='relu'))
    model.add(tfkl.Reshape((output_shape[-2],output_shape[-1])))
    model.add(tfkl.Conv1D(output_shape[-1], 1, padding='same'))

    model.compile(loss=tfk.losses.MeanSquaredError(), optimizer=tfk.optimizers.Adam(), metrics=['mae'])

    # Return the model
    return model

# %%
output_shape
# Out:
# (864, 7)

# %%
input_shape
# Out:
# (1600, 7)

# %%
model = build_wavenet(input_shape, output_shape)
model.summary()
tf.keras.utils.plot_model(model, expand_nested=True)
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_28 (Conv1D)          (None, 1600, 20)          300
#
#  conv1d_29 (Conv1D)          (None, 1600, 20)          820
#
#  conv1d_30 (Conv1D)          (None, 1600, 20)          820
#
#  conv1d_31 (Conv1D)          (None, 1600, 20)          820
#
#  conv1d_32 (Conv1D)          (None, 1600, 20)          820
#
#  conv1d_33 (Conv1D)          (None, 1600, 20)          820
#
#  conv1d_34 (Conv1D)          (None, 1600, 20)          820
#
#  conv1d_35 (Conv1D)          (None, 1600, 20)          820
#
#  conv1d_36 (Conv1D)          (None, 1600, 10)          210
#
#  global_average_pooling1d_1   (None, 10)               0
#  (GlobalAveragePooling1D)
#
#  dense_3 (Dense)             (None, 6048)              66528
#
#  reshape_3 (Reshape)         (None, 864, 7)            0
#
#  conv1d_37 (Conv1D)          (None, 864, 7)            56
#
# =================================================================
# Total params: 72,834
# Trainable params: 72,834
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Train the model
history = model.fit(
    x = X_train,
    y = y_train,
    batch_size = batch_size,
    epochs = epochs,
    validation_split=.1,
    callbacks = [
        tfk.callbacks.EarlyStopping(monitor='val_loss', mode='min', patience=10, restore_best_weights=True),
        tfk.callbacks.ReduceLROnPlateau(monitor='val_loss', mode='min', patience=5, factor=0.5, min_lr=1e-5)
    ]
).history
# Out:
# Epoch 1/200
# 85/85 [==============================] - 15s 59ms/step - loss: 0.2082 - mae: 0.4068 - val_loss: 0.1402 - val_mae: 0.3086 - lr: 0.0010
# Epoch 2/200
# 85/85 [==============================] - 4s 41ms/step - loss: 0.1079 - mae: 0.2698 - val_loss: 0.0818 - val_mae: 0.2312 - lr: 0.0010
# Epoch 3/200
# 85/85 [==============================] - 4s 42ms/step - loss: 0.0621 - mae: 0.1951 - val_loss: 0.0527 - val_mae: 0.1826 - lr: 0.0010
# Epoch 4/200
# 85/85 [==============================] - 4s 42ms/step - loss: 0.0410 - mae: 0.1523 - val_loss: 0.0392 - val_mae: 0.1542 - lr: 0.0010
# Epoch 5/200
# 85/85 [==============================] - 4s 41ms/step - loss: 0.0316 - mae: 0.1318 - val_loss: 0.0331 - val_mae: 0.1380 - lr: 0.0010
# Epoch 6/200
# 85/85 [==============================] - 4s 42ms/step - loss: 0.0274 - mae: 0.1230 - val_loss: 0.0307 - val_mae: 0.1298 - lr: 0.0010
# Epoch 7/200
# 85/85 [==============================] - 4s 41ms/step - loss: 0.0252 - mae: 0.1186 - val_loss: 0.0282 - val_mae: 0.1255 - lr: 0.0010
# Epoch 8/200
# 85/85 [==============================] - 4s 41ms/step - loss: 0.
200
# 85/85 [==============================] - 4s 42ms/step - loss: 0.0139 - mae: 0.0865 - val_loss: 0.0183 - val_mae: 0.0984 - lr: 0.0010
# Epoch 37/200
# 85/85 [==============================] - 4s 41ms/step - loss: 0.0136 - mae: 0.0857 - val_loss: 0.0184 - val_mae: 0.0983 - lr: 0.0010
# Epoch 38/200
# 85/85 [==============================] - 4s 42ms/step - loss: 0.0135 - mae: 0.0853 - val_loss: 0.0181 - val_mae: 0.0974 - lr: 0.0010
# Epoch 39/200
# 85/85 [==============================] - 4s 42ms/step - loss: 0.0134 - mae: 0.0848 - val_loss: 0.0185 - val_mae: 0.0988 - lr: 0.0010
# Epoch 40/200
# 85/85 [==============================] - 4s 42ms/step - loss: 0.0133 - mae: 0.0845 - val_loss: 0.0179 - val_mae: 0.0971 - lr: 0.0010
# Epoch 41/200
# 85/85 [==============================] - 4s 46ms/step - loss: 0.0132 - mae: 0.0841 - val_loss: 0.0177 - val_mae: 0.0963 - lr: 0.0010
# Epoch 42/200
# 85/85 [==============================] - 4s 44ms/step - loss: 0.0130 - mae: 0.0834 - val_loss: 0.0175 - val_mae: 0.0967 - lr: 0.0010
# Epoch 43/200
# 85/85 [==============================] - 4s 46ms/step - loss: 0.0128 - mae: 0.0830 - val_loss: 0.0177 - val_mae: 0.0969 - lr: 0.0010
# Epoch 44/200
# 85/85 [==============================] - 4s 43ms/step - loss: 0.0126 - mae: 0.0824 - val_loss: 0.0176 - val_mae: 0.0979 - lr: 0.0010
# Epoch 45/200
# 85/85 [==============================] - 4s 42ms/step - loss: 0.0126 - mae: 0.0823 - val_loss: 0.0174 - val_mae: 0.0980 - lr: 0.0010
# Epoch 46/200
# 85/85 [==============================] - 4s 41ms/step - loss: 0.0123 - mae: 0.0814 - val_loss: 0.0173 - val_mae: 0.0982 - lr: 0.0010
# Epoch 47/200
# 85/85 [==============================] - 4s 42ms/step - loss: 0.0122 - mae: 0.0809 - val_loss: 0.0169 - val_mae: 0.0965 - lr: 0.0010
# Epoch 48/200
# 85/85 [==============================] - 4s 42ms/step - loss: 0.0121 - mae: 0.0806 - val_loss: 0.0170 - val_mae: 0.0970 - lr: 0.0010
# Epoch 49/200
# 85/85 [==============================] - 3s 41ms/step - loss: 0.0120 - mae: 0.0802 - val_loss: 0.0171 - val_mae: 0.0971 - lr: 0.0010
# Epoch 50/200
# 85/85 [==============================] - 4s 41ms/step - loss: 0.0119 - mae: 0.0798 - val_loss: 0.0167 - val_mae: 0.0952 - lr: 0.0010
# Epoch 51/200
# 85/85 [==============================] - 4s 41ms/step - loss: 0.0119 - mae: 0.0798 - val_loss: 0.0168 - val_mae: 0.0963 - lr: 0.0010
# Epoch 52/200
# 85/85 [==============================] - 4s 42ms/step - loss: 0.0118 - mae: 0.0794 - val_loss: 0.0170 - val_mae: 0.0975 - lr: 0.0010
# Epoch 53/200
# 85/85 [==============================] - 4s 42ms/step - loss: 0.0118 - mae: 0.0792 - val_loss: 0.0172 - val_mae: 0.0980 - lr: 0.0010
# Epoch 54/200
# 85/85 [==============================] - 4s 41ms/step - loss: 0.0117 - mae: 0.0788 - val_loss: 0.0170 - val_mae: 0.0974 - lr: 0.0010
# Epoch 55/200
# 85/85 [==============================] - 4s 42ms/step - loss: 0.0116 - mae: 0.0786 - val_loss: 0.0175 - val_mae: 0.0984 - lr: 0.0010
# Epoch 56/200
# 85/85 [==============================] - 4s 42ms/step - loss: 0.0115 - mae: 0.0781 - val_loss: 0.0169 - val_mae: 0.0966 - lr: 5.0000e-04
# Epoch 57/200
# 85/85 [==============================] - 4s 42ms/step - loss: 0.0115 - mae: 0.0780 - val_loss: 0.0170 - val_mae: 0.0968 - lr: 5.0000e-04
# Epoch 58/200
# 85/85 [==============================] - 4s 41ms/step - loss: 0.0115 - mae: 0.0779 - val_loss: 0.0168 - val_mae: 0.0966 - lr: 5.0000e-04
# Epoch 59/200
# 85/85 [==============================] - 4s 42ms/step - loss: 0.0115 - mae: 0.0778 - val_loss: 0.0170 - val_mae: 0.0971 - lr: 5.0000e-04
# Epoch 60/200
# 85/85 [==============================] - 4s 42ms/step - loss: 0.0114 - mae: 0.0777 - val_loss: 0.0169 - val_mae: 0.0960 - lr: 5.0000e-04

# %%
best_epoch = np.argmin(history['val_loss'])
plt.figure(figsize=(17,4))
plt.plot(history['loss'], label='Training loss', alpha=.8, color='#ff7f0e')
plt.plot(history['val_loss'], label='Validation loss', alpha=.9, color='#5a9aa5')
plt.axvline(x=best_epoch, label='Best epoch', alpha=.3, ls='--', color='#5a9aa5')
plt.title('Mean Squared Error (Loss)')
plt.legend()
plt.grid(alpha=.3)
plt.show()

plt.figure(figsize=(17,4))
plt.plot(history['mae'], label='Training accuracy', alpha=.8, color='#ff7f0e')
plt.plot(history['val_mae'], label='Validation accuracy', alpha=.9, color='#5a9aa5')
plt.axvline(x=best_epoch, label='Best epoch', alpha=.3, ls='--', color='#5a9aa5')
plt.title('Mean Absolute Error')
plt.legend()
plt.grid(alpha=.3)
plt.show()

plt.figure(figsize=(18,3))
plt.plot(history['lr'], label='Learning Rate', alpha=.8, color='#ff7f0e')
plt.axvline(x=best_epoch, label='Best epoch', alpha=.3, ls='--', color='#5a9aa5')
plt.legend()
plt.grid(alpha=.3)
plt.show()

# %%
model.save('wavenet')
# model = tfk.models.load_model('DirectForecasting')
# Out:
# WARNING:absl:Function `_wrapped_model` contains input name(s) Input with unsupported characters which will be renamed to input in the SavedModel.
# INFO:tensorflow:Assets written to: wavenet/assets
# INFO:tensorflow:Assets written to: wavenet/assets

# %%
# Predict the test set 
predictions = model.predict(X_test)
print(predictions.shape)

mean_squared_error = tfk.metrics.mse(y_test.flatten(),predictions.flatten())
mean_absolute_error = tfk.metrics.mae(y_test.flatten(),predictions.flatten())
mean_squared_error.numpy(), mean_absolute_error.numpy()
# Out:
# (554, 864, 7)
# (0.021518275, 0.11097714)

# %%
def inspect_multivariate_prediction(X, y, pred, columns, telescope, idx=None):
    if(idx==None):
        idx=np.random.randint(0,len(X))

    figs, axs = plt.subplots(len(columns), 1, sharex=True, figsize=(17,17))
    for i, col in enumerate(columns):
        axs[i].plot(np.arange(len(X[0,:,i])), X[idx,:,i])
        axs[i].scatter(np.arange(len(X[0,:,i]), len(X_train[0,:,i])+telescope), y[idx,:,i], color='orange')
        axs[i].scatter(np.arange(len(X[0,:,i]), len(X_train[0,:,i])+telescope), pred[idx,:,i], color='green')
        axs[i].set_title(col)
        axs[i].set_ylim(0,1)
    plt.show()

# %%
inspect_multivariate_prediction(X_test, y_test, predictions, target_labels, telescope)

# %%
maes = []
for i in range(predictions.shape[1]):
    ft_maes = []
    for j in range(predictions.shape[2]):
        ft_maes.append(np.mean(np.abs(y_test[:,i,j]-predictions[:,i,j]), axis=0))
    ft_maes = np.array(ft_maes)
    maes.append(ft_maes)
maes = np.array(maes)

# %%
future_predictions = model.predict(future)

# %%
figs, axs = plt.subplots(len(target_labels), 1, sharex=True, figsize=(17,17))
for i, col in enumerate(target_labels):
    axs[i].plot(np.arange(len(future[0,:,i])), future[0,:,i])
    axs[i].plot(np.arange(len(future[0,:,i]), len(future[0,:,i])+telescope), future_predictions[0,:,i], color='orange')
    axs[i].fill_between(
        np.arange(len(future[0,:,i]), len(future[0,:,i])+telescope), 
        future_predictions[0,:,i]+maes[:,i], 
        future_predictions[0,:,i]-maes[:,i], 
        color='orange', alpha=.3)
    axs[i].set_title(col)
    # axs[i].set_ylim(0,1)
plt.show()
